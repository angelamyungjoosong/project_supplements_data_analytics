# %% [markdown]
# ### 스키니랩 다이어트보조제

# %%
from selenium import webdriver
import time
import pandas as pd 
import pymongo as mg

# %%
browser = webdriver.Chrome(executable_path='../chromedriver.exe')

# %%
browser.get('https://www.skinnylab.co.kr/shop/diet/cissus?')

# %% [markdown]
# ### 글 가져오기
# - 상품 클릭 tag: #goods > div.container-wrap > div > ul > li:nth-child(1)
# - 상품명 tag: #goodsDetail > div.content > div.head > h2 > span.main
# - 상품리뷰 클릭 tag: #content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)
# - 리뷰 번들 tag: #review > div.review-accordion > dl:nth-child({})
# - 리뷰 작성자 tag: .name
# - 리뷰 별점 tag: .fill  / #review > div.review-accordion > dl:nth-child(1) > dt > div > p.grade-star.small
# - 리뷰 날짜 tag: .date
# - 리뷰 내용 tag: .review-contents-detail
#
# ### 페이지네이션
# - next page : #review > div.common-pagination > div > a.paging-btn.next

# %% [markdown]
# ### 컬럼
# product_name, review_name, review_title, review_content, review_date, review_rating

# %%
#페이지당 상품 묶음 개수 체크        
post_bundle = browser.find_elements_by_css_selector('.main')
len(post_bundle)
# Out:
# 10

# %%
#상품 이름 및 클릭 
browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({})'.format(1)).click()
product_name = browser.find_element_by_css_selector('#goodsDetail > div.content > div.head > h2 > span.main').text
product_name
# Out:
# '스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분'

# %%
#상품리뷰 클릭 
browser.find_element_by_css_selector('#content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)').click()

# %%
#리뷰 번들 
review_bundle = browser.find_element_by_css_selector('#review > div.review-accordion > dl:nth-child({})'.format(10))

# %%
#글쓴이, 내용, 날짜, 별점 
review_name = review_bundle.find_element_by_css_selector('.name').text
review_content = review_bundle.find_element_by_css_selector('.review-contents-detail').text
review_date = review_bundle.find_element_by_css_selector('.date').text
review_rating = review_bundle.find_element_by_css_selector('.fill').get_attribute('aria-label')

# %%
[product_name, review_name, review_content, review_date, review_rating]
# Out:
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분',
#  '이*정',
#  '거의6**째먹고잇어요 맛은먹을만한데가격이너,무비싸네요 ㅜ ***.분해해준다길래먹고잇어요 가격이너무부담되네요',
#  '2021.12.14',
#  None]

# %%
# review_list =[]
# for product in range(1,10):
#     browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({})'.format(product)).click()
#     time.sleep(1)
#     browser.find_element_by_css_selector('#content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)').click()
#     try:
#         for next_page in range(1,100):
#             try:
#                 time.sleep(1)
#                 for number in range(1,10):
#                     try:
#                         product_columns_name = [product_name, review_name, review_content, review_date, review_rating]                                        
#                         time.sleep(1)
#                         product_name = product_name = browser.find_element_by_css_selector('.main').text                                          
#                         review_bundle = browser.find_element_by_css_selector('#review > div.review-accordion > dl:nth-child({})'.format(number))
#                         try:
#                             review_name = review_bundle.find_element_by_css_selector('.name').text
#                         except: 
#                             review_name = str()
#                         try: 
#                             review_content = review_bundle.find_element_by_css_selector('.review-contents-detail').text
#                         except: 
#                             review_content = str()
#                         try:
#                             review_date = review_bundle.find_element_by_css_selector('.date').text     
#                         except: 
#                             review_date = str()
#                         time.sleep(1)
#                         single_review_list = [product_name, review_name, review_content, review_date]
#                         print(single_review_list)
#                         review_list.append(single_review_list)
#                     except:
#                 browser.find_element_by_css_selector('.paging-btn next').click
#             except:  
#     except: 
#          pass
# Out:
#   Cell In[149], line 33
#     browser.find_element_by_css_selector('.paging-btn next').click
#     ^
# IndentationError: expected an indented block after 'except' statement on line 32

# %%
import time

client = mg.MongoClient(host='mongodb://localhost:27017')
database = client['project_supplements_data_analysis']
collection = database['skinnylab_reviews']

product_columns_name = ['product_name', 'review_name', 'review_content', 'review_date', 'review_rating']
review_list = []

for product in range(1, 10):
    product_name = browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({}) > div > a > figure > figcaption > p.title > span'.format(product)).text
    browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({})'.format(product)).click()
    
    time.sleep(1)
    
    # 리뷰 클릭
    browser.find_element_by_css_selector('#content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)').click()
    time.sleep(1)
    try:
        for next_page in range(1, 100):
            try:
                for number in range(1, 11):
                    try:
                        review_bundle = browser.find_element_by_css_selector('#review > div.review-accordion > dl:nth-child({})'.format(number))
                        
                        try:
                            review_name = review_bundle.find_element_by_css_selector('.name').text
                        except:
                            review_name = ""
                        
                        try:
                            review_content = review_bundle.find_element_by_css_selector('.review-contents-detail').text
                        except:
                            review_content = ""
                        
                        try:
                            review_date = review_bundle.find_element_by_css_selector('.date').text
                        except:
                            review_date = ""
                          
                        try: 
                            review_rating = ""  
                        except:
                            review_rating = ""
                            
                        single_review_list = [product_name, review_name, review_content, review_date, review_rating]
                        print(single_review_list)
                        time.sleep(1)
                        review_list.append(single_review_list)
                        df_review = pd.DataFrame(data= review_list, columns=product_columns_name)
                        data_dict = df_review.to_dict(orient='records')
                        collection.insert_many(data_dict)
                        browser.execute_script("window.scrollTo(0, 150)")
                        time.sleep(1)
                    except Exception as e:
                        break
                        print(f"Error occurred while scraping review data: {e}")
                # 페이지네이션을 찾아서 클릭
                next_button = browser.find_element_by_xpath('//*[@class="paging-btn next"]')
                next_button.click()
                time.sleep(1)
            
            except Exception as e:
                break
                print(f"Error occurred while navigating to the next page: {e}")
            time.sleep(1)
    except Exception as e:
        pass
        print(f"Error occurred while scraping product data: {e}")
    finally:
        browser.get('https://www.skinnylab.co.kr/shop/diet/cissus?')
        time.sleep(5)
# Close the browser when done
browser.quit()
# Out:
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*균', '푸짐한선물 감사합니다.', '2022.03.30', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '정*리', '만족합니다', '2022.01.08', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*정', '거의6**째먹고잇어요 맛은먹을만한데가격이너,무비싸네요 ㅜ ***.분해해준다길래먹고잇어요 가격이너무부담되네요', '2021.12.14', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분',
'']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*민', '이번에 다**트 꼭 성공하려고 큰맘먹고 주문했어요!! 꾸준히 먹어보고 또 시키려구요~', '2021.04.05', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'g*******', '빠른배송 감사합니다.', '2021.04.02', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'e*********', '엄마가 시서스가 뱃*에 좋다며 자꾸 말씀하셔서 샀어요. 8주치는 마셔야 효*있겠나싶어서 8주치샀어요. 조깅하실때 물대신 마시시라고 말씀드렸구요. 효*있으면 계속사드릴려구용', '2021.04.02', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'e*********', '엄마가 시서스시서스 그래서 이것저것 검색하다가 엄마 ****에 도움되시라고 사드립니다. 8주마셔야 **있는거 같아보여서 8주치 샀어요. 그냥 마시기만 하는것보다 조깅도 같이하면서 마시니 **가 있었으면 좋겠네요.', '2021.04.02', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*진', '두번째 구매입니다~이번엔 가족에게 선물했어요 먹어보니 효*가 있는듯해서 함께먹으려 주문합니다', '2021.03.23', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '오*숙', 'Tv에서 시서스로 다**트 성공하신분을 보고 관심 갖게 됐어요..가루로 되어 있어 물을 잘 안마시는 저한테 딱이네요. 보틀도 주셔서 먹기에 간편하고 사은품도 많이 주셨네요^^', '2021.03.12', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*숙', '구수하니 먹기 편해요', '2021.03.11', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*늘', '시서스가 다**트에 좋다고 하길래 한번 사봤는데 진짜 좋네요~(•ө•)♡ 운동해도 잘 안빠지던 체*8이 시서스 섭취로 빠지는가 얼마나 편한지 몰라요!! 맛도 진짜 엄청 구수하고 보리차?? 그런 차 종류 마시는것 같아요!@', '2021.03.08', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '서*희', '좋아요ㆍ딸과 함께 먹으려고요ㆍ운동도 같이ㆍ조금씩 식이요법도요', '2021.03.06', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '정*경', '40*이 넘어가면서 갑자기 찾아온 혈압 아직 젊은 나이라 *으로 혈압을 낮추는거 보다 다**트와 운동으로 해보자 맘을 먹고 찾아보다 시서스를 알게 되었고 시서스를 알게 되면서 또 너무 많은 제품으로 갈등하던중 알게된 스키니랩~ 일단 아직 오랜시간 **하지 않아서 잘 모르겠지만 믿음과 노력이 있으면 되지 않을까 생각합니다 열심히 먹고 *빼서 글 또 올리겠습니다', '2021.03.05', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '고*서', '맛있게 먹고 ***뺄수있어서 좋아요 고소해서 맛있고 물과 함께 마시니 수분충전도 듬뿍 ㅎㅎ 그래서 재구매 할수밖에 없네요! 사은품도 통크게 주셔서 감사합니다 ♡', '2021.03.04', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '고*서', '체** 쏙쏙빠지는 시서스 재구매합니다♡ 한봉씩 스틱포장이여서 깔끔하고 가지고 다니기도 너무 좋아요^^ 맛도 고소해서 먹기 좋고 물에 희석해먹으니 수분충전도 덩달아 하게되어서 너무 좋아요^^ 스키니랩은 사은품도 넉넉히 챙겨주셔서 착한가격으로 구입하는 기분입니다ㅎㅎ 스키니랩 최고^^', '2021.03.04', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*지', '코로나때문에 *이 쫌 쪘어요 운동도힘들고..ㅠ 그런데 엄마가 오셔서 시서스가 좋다더라하길래 바로알아보고 주문ㅋㅋ 막상 시키고보니 맛때문에 걱정했는데.. 물처럼 먹기좋아요 물도잘안먹는데 의식해서 챙겨먹을려고 가루로~~ 구수하니 좋아요~ 사은품..대박이네요~', '2021.02.27', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*지', '상품보다 사은품이 더많은거같네요~ 알*으로사려다가 다**트때는 물을 마니 먹으라해서 일부러 가루로샀어요~ 맛이 없으면 어쩌나했는데 보리차?슝늉?같이 구수하게 맛있어요~ 물량은 본인하테맞게 조절하면 되는거같구.. *이 잘빠지면 좋겠는데 이것만먹어선 안되겠죠? 그래도 음식조절하며 꾸준히 마실려구요~', '2021.02.27', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'a*******', '다른거 먹다가 이게 좋아서 다시 구매요', '2021.02.19', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '윤*일', '시서스 다**트 유명해서 사봤오요. **** 섭취를 좀 줄이면서 마셔보려구요. 효* 기대해요~ 사진이 잘 안올라가서 아쉬워요ㅡㅜ', '2021.01.28', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'k*******', '물에 잘녹고 먹기 편해요~~~', '2021.01.25', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '강*정', '다**트 8주도전하려고 주문했어요!! 저는 시서스만 주문했는데~ 이것저것 많이 챙겨주셔서 택배 열어보고 너무 기분이 좋았습니다^^ 다**트때 물 많이 마시면 좋으니 사은품으로 주신 보틀에 500ml 물 담아서 오전에 한봉, 오후에 한봉 타서 먹고 있어요~ 구수한 누릉지차 같은 맛이라 맹물 먹기 싫어하는 저도 맛있게 먹고 있습니다. 이렇게 다**트식품은 처음 사보는데 효* 잘 보고 후기 막막 올리구~~ 재주문하고 싶네요!!!!', '2021.01.25', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'b*******', '두번째 먹어요~날씬해지길~^^', '2021.01.17', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 's*******', '시서스 예전에도 먹었는데 몸이 좀 무거운 느낌이라 다시 먹으려구요', '2021.01.11', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '정*실', '좋아요 다**트뿐만아니라 관*에도 좋아서 꾸준히 먹는 제품입니다 !!굿굿!!', '2021.01.10', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*은', '다**트 시작하려고 마음 먹어서 시켰어요! 다른 다**트 제품 먹었을 때는 맛이 없어서 못먹었는데 이거는 구수하고 그냥 물처럼 잘 넘어가서 먹기 편했어요 ㅎㅎ 다들 효* 있다고 하니 다 먹고 재구매할 의향도 있어요:)', '2021.01.05', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*은', '아직 며칠 먹지 않았지만 맛도 생각보다 구수하고 물 같아서 좋고, 배송도 빨라서 너무 좋았어요 !! **도 있다고 하니 재구매 의사 있습니다 ㅎㅎ', '2021.01.05', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '전*덕', '효*있어서 주문했어요 아침저녁 잊지않고 한포씩 뜯어서 물에 타먹기 편해서 좋습니다 앞으로도 더 구매의향 있습니다', '2020.12.28', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*희', '시서스를 주문하고 입맛에 안맛아서 못먹으면 어쩌나 걱정했어요 따뜻한 물에 타서(안뭉치고 잘녹아요) 한입 먹어보니 구수한 숭늉맛이 나요ㅋㅋㅋ 넘 맛있어서 물 싫어하는 제가 원샷 했네요ㅋㅋ *만 잘 빠지면 더 바랄게 없네요 :)', '2020.12.17', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '고*규', '별이 5개 밖에 없는 게 아쉽네요 그냥 여기가 최고입니다.', '2020.12.16', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '임*은', '사진이안올려졌어요ㅠㅠ', '2020.12.15', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '임*은', '친정엄마두 드셔보시라구 권해주었어어요^^ 내돈으로주고산 두번째 입니다', '2020.12.15', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'k*******', '늘 주문해서 먹어요~', '2020.12.14', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*서', '조아요', '2020.12.12', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*서', '**를 기대해봅니다^^', '2020.12.12', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*서', '알*으로만 구매하다가 가루로 된게 더좋아서 구매하게되었어요 물에다가 타서먹으니까 물도많이먹게되고 보리차처럼 구수하니 조아요 이거먹으면서 효*좀봤음좋겠어요~^^ ***에가서 소*을 많이싸서 좋은거같아요^^', '2020.12.12', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'z*******', '항상 재구매합니다 **가 빠지는거같아요', '2020.11.28', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*랑', '곡물차처럼 맛이 좋아서 자주 먹게 되네요 ?', '2020.11.20', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*랑', '엄마가 먼저 3**정도 마셔보더니 아침에 붓*도 덜하고 너무좋다고 하시네요 류**스가 있으셔서 평생*을 드셔야해서 .. 몸도 자주 붓고 염*도 있으시고.. 그런데 아침에 덜 *어서 편하다고 하시네요 그래서 또 주문합니다. 혹시나 해서 저도 하나 마셔봤는데 곡물차처럼 맛있고 좋네요 앞으로 꾸준히 마셔볼 생각입니다.', '2020.11.20', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '구*선', '하루 2포 꼭 챙겨먹고있어요. 먹으니 몸도 가벼워지는 느낌이고 편안하네요 엄마랑 나눠먹고있는데 재구매 의사 100%입니다. 가격이 부담인데 좋은 이벤트 많이해주세요^^', '2020.11.08', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'k*******', '*빠지는건 잘모르겠지만 소화는 잘돼요~~~~', '2020.11.07', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'j*******', '배송도 빠르고 상품도 만족스럽습니다', '2020.10.25', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*지', '지금 ***째 계속먹고있는데~ 식단조절 안했는데 *지더라고요 조금 관리하면 *니 *질거같아요 참고로 전 *후 라 *이 잘안*지더라고요 근데 지금 계속 *용하니까 *욕 *기는것도 없고 물만 마니 먹게되더라고요 가격은 좀나가지만 계속 *용하려고요 괜히 이름값 하는거 아닌가봐요 ㅎㅎ', '2020.10.20', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*지', '친정엄마가 한번드시더니 계속주문해달라고 하네요 친정엄마가 *과를 마니보셨어요 앞으로 *욱 부탁한다고 하네요 ㅋ ㅋ', '2020.10.20', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'g*******', '먼저 한두어박스 먹어보구서 재구재했어요. 슝늉처럼 구수해서 먹기 좋습니다 ㅎ', '2020.10.13', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'k*******', '늘 먹고있는 제품이에요', '2020.10.07', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '임*경', '엄마친구들까지 전파완료! 또 시키러왔습니다 ㅜㅜ 시서스 웨안사? 진짜 짱입니다. 고소하니 존맛입니다! 없으면 불안해서 쌓아놓고 먹어요 ㅋㅋㅋ', '2020.10.03', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '전*미', '요거요거 넘나 구수하고 맛있어요~ 신랑도 좋다고 하네요~ 우리아들은 배*도 전에 먹던 시서스보다 훨씬 좋은것 같다네요^^', '2020.09.26', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '문*희', '친구가 효*를 보고있다고해서 믿고 사봤어요~마침 할인도 하네요~근데 뭔가 사은품이랑 같이 한가득왔네요^~^감사해요~많이파세요', '2020.09.18', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'a*******', '항상 시키던거이요.', '2020.09.14', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'd*******', '배송도 빠르고, 제품도 좋습니다.', '2020.09.14', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '박*성', '요즘은 무더운 날씨에 아무래도 물을 많이 찾게 되는데 딸아이가 생수의 맛에 예민해서 학교나 학원갈 때 타서 먹으라고 챙겨주고 있답니다. 분명 처음에는 시서스가 다**트에 도움이 된다는 정보를 듣고 먹기 시작했는데 이제는 그냥 생수를 먹기 싫어서 쟁여놓게 되네요. 덕분에 수분섭취량도 늘고 다**트에도 도움이 되는 일석이조의 효*를 볼 수 있을 것 같아 앞으로도 꾸준히 구매할 것 같아요~', '2020.08.19', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '임*리', '매일 아침 시서스 물로 하루를 시작할 수 있어 너무 좋아요. 큰 변화는 아직 잘 모르겠지만 꾸준히 먹어보려고 합니다 ^^ 다 먹은 후에 또 재구매 할께요~', '2020.08.11', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*망', '시네트롤자몽오렌지 먹어보고 시서스는 어떤지 궁금해서 구입했어요~ 누룽지맛 난다고해서 더 괜찮을것 같아용 시네트롤은 좀 시큼하거든용', '2020.08.11', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*지', '벌써 네번째 구매하네요 저는 개인적으로 효*를보아서요 친정엄마도 주문해드려요 엄마가 **하기도 편하다고 하네요 앞으로 계속 부탁좀 하시네요', '2020.08.02', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '이*지', '또 재구매하네요 **후 *이 마니 안빠져서 고생중이였는데 꾸준히 **하니까 *이 점점 빠지네요 아기 아기가 어려서 운동도 같이 못하지만 식이요법 좀 하면서 하니까 **가 나오더라고요 계속 쭈욱 ~~', '2020.08.02', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '고*서', '재구매했어요^^ 이 제품 너무 좋아용♡♡♡', '2020.07.25', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '고*서', '꾸준히 먹고있는 시서스! 맛도 고소하고 덕분에 물도 많이 섭취하게되고 체*방도 쏙쏙 빠져서 넘 좋아용^^ 꾸준히 **하게되네요 요거 안 마신날은 몸이 무겁게 느껴지네요 시서스 강츄^-^♡', '2020.07.25', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '고*서', '이번에도 다 떨어져서 8주분 구매했어용 시서스 꾸준히 먹고있어요 맛도 고소한게 좋구요^^ 물론 ***도 쏙쏙 잘 빠지고 이거 먹으면서 물도 더 잘마시게되고 여러모로 좋으네용♡', '2020.07.25', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'w*******', '아직 잘 모르겠어요 좀더 먹어봐야 할듯', '2020.07.25', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*현', '서비스도감사합니다~^^ 추천받아구매했고요~부담없이 잘먹구있습니다^^ 시서스는 고소하니운동하고마시면딱!이구요~ 방탄커피는 출출하니간식당길때 마셔주니좋은거같아요..향이좋네요~고소하니.. 열심히먹고*빼보겠습니다>.<', '2020.07.24', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '준***♡', '다른곳에서 구매하다가 지인분께서 추천해주셔서 가입하고 재구매했는데 가격도 저렴하고 사은풒까지 넣어주셔서 감사합니다', '2020.07.21', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', 'j*******', '배송도 빠르구요..재구매 했습니다~~^^', '2020.07.18', '']
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분', '김*석', '1주일 **후 후기 첨엔 사놓고 겁먹었어요 ~ 맛이 비위상하지않을까 부작용 있지않을까 그런데 맛도 구수해서 목넘김도 편하네요..^^ 그리고 아직 다른건 모르겠지만평상시처럼 **** 잘먹고 있는데 더이상 바늘이 올라가지 않네요~', '2020.07.18', '']
