# %% [markdown]
# ### 스키니랩 다이어트보조제

# %%
from selenium import webdriver
import time
import pandas as pd 
import pymongo as mg

# %%
browser = webdriver.Chrome(executable_path='../chromedriver.exe')

# %%
browser.get('https://www.skinnylab.co.kr/shop/diet/cissus?')

# %% [markdown]
# ### 글 가져오기
# - 상품 클릭 tag: #goods > div.container-wrap > div > ul > li:nth-child(1)
# - 상품명 tag: #goodsDetail > div.content > div.head > h2 > span.main
# - 상품리뷰 클릭 tag: #content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)
# - 리뷰 번들 tag: #review > div.review-accordion > dl:nth-child({})
# - 리뷰 작성자 tag: .name
# - 리뷰 별점 tag: .fill  / #review > div.review-accordion > dl:nth-child(1) > dt > div > p.grade-star.small
# - 리뷰 날짜 tag: .date
# - 리뷰 내용 tag: .review-contents-detail
#
# ### 페이지네이션
# - next page : #review > div.common-pagination > div > a.paging-btn.next

# %% [markdown]
# ### 컬럼
# product_name, review_name, review_title, review_content, review_date, review_rating

# %%
#페이지당 상품 묶음 개수 체크        
post_bundle = browser.find_elements_by_css_selector('.main')
len(post_bundle)
# Out:
# 10

# %%
#상품 이름 및 클릭 
browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({})'.format(1)).click()
product_name = browser.find_element_by_css_selector('#goodsDetail > div.content > div.head > h2 > span.main').text
product_name
# Out:
# '스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분'

# %%
#상품리뷰 클릭 
browser.find_element_by_css_selector('#content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)').click()

# %%
#리뷰 번들 
review_bundle = browser.find_element_by_css_selector('#review > div.review-accordion > dl:nth-child({})'.format(10))

# %%
#글쓴이, 내용, 날짜, 별점 
review_name = review_bundle.find_element_by_css_selector('.name').text
review_content = review_bundle.find_element_by_css_selector('.review-contents-detail').text
review_date = review_bundle.find_element_by_css_selector('.date').text
review_rating = review_bundle.find_element_by_css_selector('.fill').get_attribute('aria-label')

# %%
[product_name, review_name, review_content, review_date, review_rating]
# Out:
# ['스키니랩 가벼워지는 시서스 다이어트 14포 x8박스 8주분',
#  '이*정',
#  '거의6**째먹고잇어요 맛은먹을만한데가격이너,무비싸네요 ㅜ ***.분해해준다길래먹고잇어요 가격이너무부담되네요',
#  '2021.12.14',
#  None]

# %%
review_list =[]
for product in range(1,10):
    browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({})'.format(product)).click()
    time.sleep(1)
    browser.find_element_by_css_selector('#content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)').click()
    try:
        for next_page in range(1,100):
            try:
                time.sleep(1)
                for number in range(1,10):
                    try:
                        product_columns_name = [product_name, review_name, review_content, review_date, review_rating]                                        
                        time.sleep(1)
                        product_name = product_name = browser.find_element_by_css_selector('.main').text                                          
                        review_bundle = browser.find_element_by_css_selector('#review > div.review-accordion > dl:nth-child({})'.format(number))
                        try:
                            review_name = review_bundle.find_element_by_css_selector('.name').text
                        except: 
                            review_name = str()
                        try: 
                            review_content = review_bundle.find_element_by_css_selector('.review-contents-detail').text
                        except: 
                            review_content = str()
                        try:
                            review_date = review_bundle.find_element_by_css_selector('.date').text     
                        except: 
                            review_date = str()
                        time.sleep(1)
                        single_review_list = [product_name, review_name, review_content, review_date]
                        print(single_review_list)
                        review_list.append(single_review_list)
                    except:
                browser.find_element_by_css_selector('.paging-btn next').click
            except:  
    except: 
         pass
# Out:
#   Cell In[149], line 33
#     browser.find_element_by_css_selector('.paging-btn next').click
#     ^
# IndentationError: expected an indented block after 'except' statement on line 32

# %%
import time
review_list = []

for product in range(1, 10):
    browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({})'.format(product)).click()
    time.sleep(1)
    browser.find_element_by_css_selector('#content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)').click()
    
    try:
        for next_page in range(2, 111):
            try:
                # Initialize product_name here
                product_name = browser.find_element_by_css_selector('.main').text
                
                for number in range(1, 10):
                    try:
                        review_bundle = browser.find_element_by_css_selector('#review > div.review-accordion > dl:nth-child({})'.format(number))
                        
                        try:
                            review_name = review_bundle.find_element_by_css_selector('.name').text
                        except:
                            review_name = ""
                        
                        try:
                            review_content = review_bundle.find_element_by_css_selector('.review-contents-detail').text
                        except:
                            review_content = ""
                        
                        try:
                            review_date = review_bundle.find_element_by_css_selector('.date').text
                        except:
                            review_date = ""
                        
                        single_review_list = [product_name, review_name, review_content, review_date]
                        print(single_review_list)
                        review_list.append(single_review_list)
                    except Exception as e:
                        print(f"Error occurred while scraping review data: {e}")
                
                  # 페이지네이션을 찾아서 클릭
                next_button = browser.find_element_by_css_selector("#review > div.common-pagination > div > a.paging-btn.next")
                next_button.click()
                
            except Exception as e:
                print(f"Error occurred while navigating to the next page: {e}")
    except Exception as e:
        print(f"Error occurred while scraping product data: {e}")

# Close the browser when done
browser.quit()
# Out:
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ...
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
#
# ['', '가*****************♡', '노력만하시면. 구입은. 후회안합니다.  다만. 먹다가. 안먹으면.  다시. 그대로. 한순간변해요.  4년동한먹었던 나.   6**먹다가. 2달끊었는데.  다시. 복궈가 되네요.  참고하시고.  운동 하시면서.  먹는다면. 추천.      밥한끼안먹고. 이걸로. 2스틱. 500m. 물량을. 섭취한다면.  추천드립니다.  까놓고애기하니. 이글을. 관리자. 님들이 보신다면 좋아하지는않겠죠.   꾸준히 게속 드셔야합니다.   안그럼 비추천드려요.  😀   ^^', '2022.12.28']
# ['', '강*림', '먹기편하고 맛도 좋아요. 3주차라 **는 좀더 봐야할거 같아요.', '2022.10.09']
# ['', '정*', '아직까지 드라마틱한 **는 없지만 더 찌지 않았어요 \n맛있어서 먹는데는 부담없어요. \n여섯달까지 쭉 먹어보렵니다 ', '2022.09.05']
# ['', '임*하', '*국 추천받아서 ** 감량을 위해 구입했습니다. 부담스럽지 않은 맛에 아침저녁 먹기 전 1회씩 총 2회를 하루에 먹고 있는데요. 뭔가 섭취 후에 배출이 잘되는 느낌입니다~ 꾸준히 먹어보려구요. ', '2022.08.01']
# ['', '김*희', '시서스를 꾸준히 먹고 있는데\n매번 선물로 받다가 이번엔 제가 구매를 해야해서 스키랩으로 들어가 회원까지 가입하고 시서스를 구매했내요\n비오틴 사은품과 풋사과 잴리\n먹어보고 싶었던것을 시서스 주문으로 함께ㅡ받아보니 더없이 좋네요\n담엔 락토페린도 그매할 예정입니다', '2022.04.13']
# ['', '심*수', '늘 먹어서 좋아요ㅎ', '2022.04.06']
# ['', '박*균', '푸짐한선물 감사합니다.', '2022.03.30']
# ['', '정*리', '만족합니다', '2022.01.08']
# ['', '이*경', '제가 시키지 않은 게 있어서 놀랬습니다.\n사은품도 넉넉히 주시고.. 감사합니다~^^\n** 볼 수 있도록 성실히 노력해 볼게요 ^^', '2022.01.02']
# Error occurred while navigating to the next page: Message: element click intercepted: Element <a href="javascript:;" class="paging-btn next">...</a> is not clickable at point (1226, 858). Other element would receive the click: <div class="order">...</div>
#   (Session info: chrome=116.0.5845.188)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[17], line 5
#       2 review_list = []
#       4 for product in range(1, 10):
# ----> 5     browser.find_element_by_css_selector('#goods > div.container-wrap > div > ul > li:nth-child({})'.format(product)).click()
#       6     time.sleep(1)
#       7     browser.find_element_by_css_selector('#content-main > div.fixed-tab-menu > div > div > ul > li:nth-child(3)').click()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:598, in WebDriver.find_element_by_css_selector(self, css_selector)
#     582 def find_element_by_css_selector(self, css_selector):
#     583     """
#     584     Finds an element by css selector.
#     585
#    (...)
#     596         element = driver.find_element_by_css_selector('#foo')
#     597     """
# --> 598     return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#goods > div.container-wrap > div > ul > li:nth-child(2)"}
#   (Session info: chrome=116.0.5845.188)
